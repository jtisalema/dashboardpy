# %% [markdown]
#  <center> <h1> Introducción - Visualización de datos </h1></center>
#
# - Docente: Edwin Jahir Rueda Rojas
# - Email: edruedaro@uide.edu.ec
#
# La visualización de datos es una herramienta que nos permite transformar información compleja, la cual no genera valor en su estado original, en representaciones gráficas que permiten comprender, analizar y tomar decisiones. Con el correcto tipo de gráficas podremos identificar patrones, tendencias y relaciones que no sería facil detectar en los datos brutos.
#
# Durante el curso nos enfocaremos en los dos tipos principales de visualizaciones:
#
# - **Exploratoria:** Se usa en una fase primaria de la visualización de datos. útil para descubrir patrones, tendencias, anomalías, etc. Lo que queremos generar son visualizaciones que permitan al usuario o analista explorar la información y a partir de ella generar hipótesis. Suelen ser interactias, para una mayor inmersión en los datos.
# - **Explicativa:** Esta visualización busca comunicar, mostrar unos análisis/hallazgos encontrados previamente (puede ser mediate unso gráficos exploratorios). Estás visualizaciones están creadas para contar una historia, resaltando conclusiones y guiando al espectador para su entendimiento.

# %% [markdown]
# El material del curso está 100% programado en python y bajo la interfaz gráfica de [Jupyter Lab](https://jupyter.org/)

# %% [markdown]
# <img src="./images/intro.png" width="100%">

# %% [markdown]
# <img src="./images/types.png" width="80%">

# %%
# !pip install matplotlib

# %% [markdown]
# <h2>Matplotlib</h2>
#
# [Matplotlib](https://matplotlib.org/stable/index.html) es una librería en python para la creación de visualizaciones estáticas e interactivas.
#
# <img src="./images/figure.png" width="40%">

# %% [markdown]
# En matplotlib existen dos tipos de formas de definir y construir visualizaciones:
# - **Explicita:** *OOS* - *object-oriented style*. Se crean la figura y los ejes, sobre los cuales se empiezan a llamar los métodos para graficar.
# - **Implicita:** Se utilizan funciones de `pyplot` para graficar. Este se encarga de gestionar el *OOS* para generar las visualizaciones.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# Ejemplo de la forma **explicita**, donde definimos un `subplot` el cual retorna una figura `fig` y unos ejes `ax`. Note que logramos graficar haciendo uso de los llamados a los ejes `ax`.

# %%
x = np.linspace(0, 2, 100)
print(x)
# Out:
# [0.         0.02020202 0.04040404 0.06060606 0.08080808 0.1010101
#  0.12121212 0.14141414 0.16161616 0.18181818 0.2020202  0.22222222
#  0.24242424 0.26262626 0.28282828 0.3030303  0.32323232 0.34343434
#  0.36363636 0.38383838 0.4040404  0.42424242 0.44444444 0.46464646
#  0.48484848 0.50505051 0.52525253 0.54545455 0.56565657 0.58585859
#  0.60606061 0.62626263 0.64646465 0.66666667 0.68686869 0.70707071
#  0.72727273 0.74747475 0.76767677 0.78787879 0.80808081 0.82828283
#  0.84848485 0.86868687 0.88888889 0.90909091 0.92929293 0.94949495
#  0.96969697 0.98989899 1.01010101 1.03030303 1.05050505 1.07070707
#  1.09090909 1.11111111 1.13131313 1.15151515 1.17171717 1.19191919
#  1.21212121 1.23232323 1.25252525 1.27272727 1.29292929 1.31313131
#  1.33333333 1.35353535 1.37373737 1.39393939 1.41414141 1.43434343
#  1.45454545 1.47474747 1.49494949 1.51515152 1.53535354 1.55555556
#  1.57575758 1.5959596  1.61616162 1.63636364 1.65656566 1.67676768
# ...

# %%
fig, ax = plt.subplots(figsize=(8, 4), layout='constrained')
ax.plot(x, x, label='linear')
ax.plot(x, x**2, label='quadratic')
ax.plot(x, x**3, label='cubic')
ax.set_xlabel('x label')
ax.set_ylabel('y label') 
ax.set_title("Simple Plot using Object-oriented style")
ax.legend();

# %% [markdown]
# En la forma **implicita** no definimos una figura o ejes. Lo que hacemos es llamar funciones de `pyplot`, y este se va encargando de construir nuestra gráfica.

# %%
plt.figure(figsize=(8, 4))
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot using pyplot-style")
plt.legend();

# %% [markdown]
# Nota: Para maoy facilidad, en esta unidad trabajaremos principalmente con la forma **implicita**.

# %% [markdown]
# ### ¿Cómo consultar la documentación?
#
# Si bien, cada librería tiene su sitio web con la documentación. En python existen dos métodos principales para consultar la documentación de un método en específico:
#
# - \<module>.\<method>?
# - help(\<module>.\<method>)

# %%
plt.plot?
# Out:
# Signature:
# plt.plot(
#     *args: 'float | ArrayLike | str',
#     scalex: 'bool' = True,
#     scaley: 'bool' = True,
#     data=None,
#     **kwargs,
# ) -> 'list[Line2D]'
# Docstring:
# Plot y versus x as lines and/or markers.
#
# Call signatures::
#
#     plot([x], y, [fmt], *, data=None, **kwargs)
#     plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
# The coordinates of the points or line nodes are given by *x*, *y*.
#
# The optional parameter *fmt* is a convenient way for defining basic
# formatting like color, marker and linestyle. It's a shortcut string
# notation described in the *Notes* section below.
#
# >>> plot(x, y)        # plot x and y using default line style and color
# >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
# >>> plot(y)           # plot y using x as index array 0..N-1
# >>> plot(y, 'r+')     # ditto, but with red plusses
#
# You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(
#     *args: float | ArrayLike | str,
#     scalex: bool = True,
#     scaley: bool = True,
#     data=None,
#     **kwargs
# ) -> list[Line2D]
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
# ...

# %% [markdown]
# <h3>Propiedades de las figuras</h3>
#
# Para definir una figura de la forma implícita lo hacemos mediante el llamado a la función [`plt.figure()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.figure.Figure.html#matplotlib.figure.Figure). En la cual podemos definir diferentes parámetros:
# - `figsize`: tupla `(width, height)` para definir el tamaño de la figura en pulgadas.
# - `facecolor`: color del fondo de la figura.
# - `constrained_layout`: Ajustar espaciado de los elementos de la figura.

# %% [markdown]
# Figura básica:

# %%
## code here ##
plt.figure()
plt.plot();

# %% [markdown]
# Fijar el tamaño de una figura:

# %%
## code here ##
plt.figure(figsize=(8,5))
plt.plot();

# %% [markdown]
# Podemos cambiar el color del fondo de la figura:

# %%
## code here ##
plt.figure(figsize=(4,2), facecolor="#A34934")
plt.plot();

# %% [markdown]
# ### Componentes de un gráfico
#
# En [Matplotlib](https://matplotlib.org/stable/index.html) podemos definir propiedades básicas de un gráfico: `title`, `legend`, `xlabel`, `ylabel`, `grid`.

# %%
## code here ##
plt.figure()
plt.title("prueba de titulo")
plt.xlabel("[cm]")
plt.ylabel("precio")
plt.grid()

# %% [markdown]
# Así mismo podemos editar/configurar los componentes:

# %%
{
    "key": "valor",
    "key1": 45
}
# Out:
# {'key': 'valor', 'key1': 45}

# %%
## code here ##
plt.figure()
fontdict = {
    'fontsize': 22,
    'color': "#A34934",
}
plt.title(label="prueba de titulo", loc="left", fontdict=fontdict)
plt.xlabel("[cm]", size=20, rotation=45, color="blue")
plt.ylabel("precio")
plt.grid()

# %% [markdown]
# <h3>Tipos de gráficos</h3>
#
# [Matplotlib](https://matplotlib.org/stable/index.html) ofrece un gran número de [representaciones gráficas](https://matplotlib.org/stable/plot_types/index.html#plot-types). Estas representaciones nos permiten graficar relaciones en base a la naturaleza de nuestros datos:
#
# - `plt.plot(**args)`: Nos permite graficar lineas, relaciones en 2D
# - `plt.scatter(**args)`: Graficos de dispersión
# - `plt.bar(**args)`: Graficos de barras
# - `plt.hist(**args)`: Nos permite graficar distribuciones
# - `plt.boxplot(**args)`: Para representar diagramas de cajas
# - `plt.violinplot(**args)`: Para representar diagramas de violín
# - `plt.pie(**args)`: Para representar proporciones

# %% [markdown]
# Exploremos `plt.plot(**args)`:
#
# Sirve para graficar relaciones funcionales o tendencias entre variables numéricas, especialmente series temporales y funciones matemáticas.

# %%
## code here ##
y = np.linspace(0,10,100)
x = np.arange(len(y))

print(y)
print(x)
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
plt.figure()
plt.title("plot")
plt.plot(x,y, color="red", ls="-.", label="l1");
plt.plot(x,y/2, label="L2")
plt.ylabel("# transacciones")
plt.xlabel("timestamp")
plt.legend();

# %% [markdown]
# También podemos modificar la información que visualizamos en nuestros ejes, a esto se le conoce como `ticks`

# %%
## code here ##
plt.figure()
plt.title("plot")
plt.plot(x,y, color="red", ls="-.", label="l1");
plt.plot(x,y/2, label="L2")
plt.ylabel("# transacciones")
plt.xlabel("timestamp")
plt.xticks(ticks=[0,50,87, 90], labels=["inicio",50,"intermedio","fin"], rotation=90)
plt.legend();

# %% [markdown]
# Si la información que debemos mostrar en los ejes (`ticks`) se sobrepone, podemos ajustar su rotación para una mejor visualización:

# %%
## code here ##
plt.figure()
plt.title("plot")
plt.plot(x,y, color="red", ls="-.", label="l1");
plt.plot(x,y/2, label="L2")
plt.ylabel("# transacciones")
plt.xlabel("timestamp", rotation=45)
plt.xticks(ticks=[0,50,87, 90], labels=["inicio",50,"intermedio","fin"], rotation=90)
plt.legend();

# %% [markdown]
# Para multiples series temporales, podemos no solo diferenciar por colores, si no por el estilo de linea, permitiendo incluso modificar su ancho:

# %%
## code here ##
plt.figure()
plt.title("plot")
plt.plot(x,y, color="black", ls="-.", label="l1", lw=6);
plt.plot(x,y/2, color="black", label="L2", ls="-")
plt.plot(x,y*2, color="black", label="L3", ls=":")
plt.ylabel("# transacciones")
plt.xlabel("timestamp")
plt.xticks(ticks=[0,50,87, 90], labels=["inicio",50,"intermedio","fin"], rotation=90)
plt.legend();

# %% [markdown]
# Exploremos `plt.scatter(**args)`:
#
# Es ideal para explorar la relación entre variables numéricas a nivel de observaciones individuales, sin asumir una tendencia continua.
#
# A diferencia de `plt.plot(**args)`, con `scatter` podemos ver como se distribuyen los datos, no la tendencia.

# %% [markdown]
# [Pandas](https://pandas.pydata.org/docs/) para estructurar y analizar datos

# %%
# !pip install pandas

# %%
#Generar datos aleatorios
import pandas as pd

np.random.seed(6)
data_size = 15
metros_cuadrados = np.random.randint(50, 150, size=data_size)
habitaciones = np.random.randint(1, 5, size=data_size)
precio = metros_cuadrados * np.random.randint(800, 1500, size=data_size)

df = pd.DataFrame({
    "metro_cuadrado": metros_cuadrados,
    "numero_habitaciones": habitaciones,
    "precio": precio
})

df.head()
# Out:
#    metro_cuadrado  numero_habitaciones  precio
# 0              60                    2   59820
# 1             123                    1  158055
# 2             149                    3  183717
# 3             134                    1  193496
# 4             129                    1  165765

# %%
df.tail()
# Out:
#     metro_cuadrado  numero_habitaciones  precio
# 10             127                    3  142113
# 11             107                    4  101329
# 12              76                    2  106172
# 13              83                    3  119188
# 14             118                    3  127912

# %%
df["numero_habitaciones"]
# Out:
# 0     2
# 1     1
# 2     3
# 3     1
# 4     1
# 5     4
# 6     4
# 7     3
# 8     2
# 9     2
# 10    3
# 11    4
# 12    2
# 13    3
# 14    3
# Name: numero_habitaciones, dtype: int32

# %%
df.numero_habitaciones
# Out:
# 0     2
# 1     1
# 2     3
# 3     1
# 4     1
# 5     4
# 6     4
# 7     3
# 8     2
# 9     2
# 10    3
# 11    4
# 12    2
# 13    3
# 14    3
# Name: numero_habitaciones, dtype: int32

# %%
df.columns
# Out:
# Index(['metro_cuadrado', 'numero_habitaciones', 'precio'], dtype='str')

# %%
df.precio.values
# Out:
# array([ 59820, 158055, 183717, 193496, 165765, 112060, 155904,  74550,
#         47277, 140250, 142113, 101329, 106172, 119188, 127912],
#       dtype=int32)

# %%
df["precio"].values
# Out:
# array([ 59820, 158055, 183717, 193496, 165765, 112060, 155904,  74550,
#         47277, 140250, 142113, 101329, 106172, 119188, 127912],
#       dtype=int32)

# %%
df.head()
# Out:
#    metro_cuadrado  numero_habitaciones  precio
# 0              60                    2   59820
# 1             123                    1  158055
# 2             149                    3  183717
# 3             134                    1  193496
# 4             129                    1  165765

# %% [markdown]
# Podemos crear relaciones entre variables:

# %% [markdown]
# LaTex: $\frac{1}{2}$

# %%
## code here ##
plt.figure(figsize=(8,5))
plt.title("Relación $m^2$ vs precio")
plt.xlabel("m^2")
plt.ylabel("precio USD")
plt.scatter(df.metro_cuadrado, df.precio);

# %% [markdown]
# Podemos añadir una tercera caracteristica a nuestro gráfico de dispersión. Esto mediante el uso del tamaño (parámetro `s`) del círculo.

# %%
## code here ##
## code here ##
plt.figure(figsize=(8,5))
plt.title("Relación $m^2$ vs precio")
plt.xlabel("m^2")
plt.ylabel("precio USD")
plt.scatter(df.metro_cuadrado, df.precio, s=df.numero_habitaciones*100);

# %% [markdown]
# Note que hicimos uso de la operación [*broadcasting*](https://numpy.org/doc/stable/user/basics.broadcasting.html)

# %% [markdown]
# <img src="https://numpy.org/doc/stable/_images/broadcasting_1.png">

# %%
a = np.array([1,4,5])
print(f"A:{a} -> A*5:{a*5}")
# Out:
# A:[1 4 5] -> A*5:[ 5 20 25]

# %% [markdown]
# También podemos agregar [anotaciones](https://matplotlib.org/stable/api/text_api.html#matplotlib.text.Annotation) sobre nuestros gráficos:

# %% [markdown]
# [Markers](https://matplotlib.org/stable/api/_as_gen/matplotlib.markers.MarkerStyle.html#matplotlib.markers.MarkerStyle) para agregar información extra a nuestros gráficos

# %%
zip(A,B)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 zip(A,B)
#
# NameError: name 'A' is not defined

# %%
plt.figure()
plt.title("Relacion de metro cuadrado vs precio")
plt.xlabel("metro cuadrado")
plt.ylabel("precio (usd)")
plt.scatter(df.metro_cuadrado, df.precio, s=df.numero_habitaciones*100, 
            color="#A34934", marker=".", label="m^2 vs precio")
for x, y, text in zip(df.metro_cuadrado, df.precio, df.numero_habitaciones):
    plt.annotate(text, (x+3, y+3))

plt.legend()
plt.grid();

# %% [markdown]
# Exploremos `plt.bar(**args)`:
#
# Representa la relación entre una variable categórica y una variable cuantitativa, permitiendo comparar magnitudes entre diferentes categorías.

# %%
## code here ##
#plt.bar(df.metro_cuadrado, df.precio, width=2,edgecolor="black" )
plt.scatter(df.metro_cuadrado, df.precio)
plt.grid(axis="x")  #both
plt.xticks(df.metro_cuadrado);

# %% [markdown]
# Ajustemos la visual del eje x para poder saber que metro cuadrado es cada barra

# %%
## code here ##

# %% [markdown]
# Exploremos los histogramas/distribuciones `plt.hist(**args)`:
#
# Representa la frecuencia de valores de una variable numérica dentro de intervalos, permitiendo analizar la distribución de los datos.

# %%
np.random.seed(6)
x_dist = np.random.randint(low=0, high=101, size=80)
print(x_dist)
# Out:
# [10 73 99 84 79 80 62 25  1 75 77 57 26 33 68 33  8  2 76 84 91 31 66  5
#  26 15 89 86 43 69 49  4 62 80 66 66 63 19 85 28 43 57  5 50 26 78 40 69
#  70 90 63 10 67 85 11  1 82 35 22 41 24 48 42 67  7 36 75 56 33 76 68 33
#  15 69 47 21 70  1  9 48]

# %%
## code here ##
result = plt.hist(x_dist, edgecolor="black")

# %% [markdown]
# Podemos ajustar la visualización para poder separar las barras

# %%
## code here ##
result = plt.hist(x_dist, edgecolor="black")
plt.grid("y")

# %% [markdown]
# Exploremos los gráficos de cajas `plt.boxplot(**args)`
#
# Muestra la distribución estadística de una variable cuantitativa, basada en cuartiles y dispersión, permitiendo identificar outliers y comparar grupos.

# %%
x_dist[0] = 1000
print(x_dist)
# Out:
# [1000   73   99   84   79   80   62   25    1   75   77   57   26   33
#    68   33    8    2   76   84   91   31   66    5   26   15   89   86
#    43   69   49    4   62   80   66   66   63   19   85   28   43   57
#     5   50   26   78   40   69   70   90   63   10   67   85   11    1
#    82   35   22   41   24   48   42   67    7   36   75   56   33   76
#    68   33   15   69   47   21   70    1    9   48]

# %%
plt.title("Distribución de las notas de los estudiantes")
plt.ylabel("calificaciones")
r = plt.boxplot(x_dist)
plt.grid(axis="y")

# %%
plt.title("Distribución de las notas de los estudiantes")
plt.xlabel("calificaciones")
x_dist[10] = 200
r = plt.boxplot(x_dist, orientation="horizontal")
plt.grid(axis="x")

# %% [markdown]
# Exploremos [`plt.violinplot(**args)`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.violinplot.html#matplotlib.axes.Axes.violinplot):
#
# Nota: Con el gráfico de violin logramos combinar los gráficos `boxplot` y de densidad o `histogram`.

# %%
plt.title("Distribución de notas")
plt.violinplot(x_dist);
plt.yticks([0,100,200,1000]);

# %% [markdown]
# Exploremos los gráficos `plt.pie(**args)` para representar proporciones:

# %%
expenses = [350, 300, 200, 500, 150]
plt.pie(expenses);

# %% [markdown]
# Podemos agregar mas información al gráfico:
#
# Note que hacemos uso del [formato string](https://docs.python.org/3/library/string.html#format-string-syntax) de Python.

# %%
### code here ###
categorias = ["comida", "transporte", "recreación", "renta", "gym"]
expenses = [350, 300, 200, 500, 150]
autopct="%1.1f%%"
plt.pie(x=expenses, labels=categorias, autopct=autopct); #colors=["blue", "red", ""]

# %% [markdown]
# <h2>Subplots en matplotlib</h2>
#
# Los [subplots o mosaicos](https://matplotlib.org/stable/users/explain/axes/mosaic.html) en matplotlib nos permiten agrupar gráficos. Estos tienen características diferentes:
#
# - [`subplots`](https://matplotlib.org/stable/api/_as_gen/matplotlib.figure.Figure.subplots.html#matplotlib.figure.Figure.subplots): Permiten generar *layouts* para agregar varios *plots* a una única figura.
#     - `nrows`: número de filas de la cuadricula
#     - `ncols`: número de columnas de la cuadricula
#
#     Donde cada posición $(i,j)$ representa una gráfica.
#
# - [`subplot_mosaic`](https://matplotlib.org/stable/api/_as_gen/matplotlib.figure.Figure.subplot_mosaic.html#matplotlib.figure.Figure.subplot_mosaic): Permite generar figuras en un espacio de cuadricula no uniforme. Por lo cual podemos combinar filas y/o columnas.
#     - `mosaic`: Lista de listas con la distribución del mosaico.

# %% [markdown]
# Profundicemos en los [`subplots`](https://matplotlib.org/stable/api/_as_gen/matplotlib.figure.Figure.subplots.html#matplotlib.figure.Figure.subplots):

# %%
# Nos permite definir el subplot, dentro del tamaño pre-definido de la figura
plt.subplots(2,3,layout='constrained',figsize=(10,5));

# %% [markdown]
# Con los subplots podemos relacionar diferentes pares de variables

# %%
### code here ###

plt.figure(figsize=(10,5), layout='constrained')
plt.subplot(2,3,4, facecolor="yellow")
plt.title("$m^2$ vs precio")
plt.scatter(df.metro_cuadrado, df.precio)

plt.subplot(2,3,2)
plt.scatter(df.numero_habitaciones, df.precio)
plt.xlabel("# habitaciones")
# Out:
# Text(0.5, 0, '# habitaciones')

# %% [markdown]
# **Nota**: Las limitaciones de los subplot se deben a que siempre se construye una cuadricula uniforme de $n$ filas por $m$ columnas, por lo cual, se genera un espacio de gráficas de $n*m$. Si no se pintan las $n*m$ gráficas, quedarán espacios vacios. A su vez, todas las gráficas tendrán el mismo tamaño, por lo cual no podemos resaltar gráficas que consideremos de mayor impacto.

# %% [markdown]
# Exploremos los [`subplot_mosaic`](https://matplotlib.org/stable/api/_as_gen/matplotlib.figure.Figure.subplot_mosaic.html#matplotlib.figure.Figure.subplot_mosaic):
#
# Nota: Para esto, debemos entender primero el concepto de mosaico:
#
# <img src="./images/mosaics.png" width="90%">

# %%
## code here ##

m = [["A", "B"],
     ["A", "C"]]

fig, axes = plt.subplot_mosaic(mosaic=m, layout="constrained")

axes["A"].set_title("metro cuadrado vs precio")
axes["A"].scatter(df.metro_cuadrado, df.precio)

axes["C"].set_title("metro cuadrado vs precio")
axes["C"].scatter(df.metro_cuadrado, df.precio)

plt.show()

# %% [markdown]
# Con los mosaicos podemos combinar filas y columnas para brindar mayor atención a gráficas en especiífico.
